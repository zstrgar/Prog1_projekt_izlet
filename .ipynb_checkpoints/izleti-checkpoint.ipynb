# %% [markdown]
# # Analiza podatkov izleti

# %%
import pandas as pd

# %%
izleti = pd.read_csv('../Prog1_projekt_izlet/Prog1_projekt_izlet/podatki_izlet/podatki_izletov.csv', index_col = 'id')

# %%
pd.options.display.max_rows = 10

# %%
izleti
# Out:
#                           ime                                    gorovje  \
# id
# 1950                     Ahac  Goriško, Notranjsko in Snežniško hribovje
# 2566               Ajdovščina  Goriško, Notranjsko in Snežniško hribovje
# 891                   Ankaran  Goriško, Notranjsko in Snežniško hribovje
# 2594    Baba (pri Javornikih)  Goriško, Notranjsko in Snežniško hribovje
# 1740               Bela stena  Goriško, Notranjsko in Snežniško hribovje
# ...                       ...                                        ...
# 2129  Zabreznik (Sv. Miklavž)  Zasavsko - Posavsko hribovje in Dolenjska
# 2748             Žagarski vrh  Zasavsko - Posavsko hribovje in Dolenjska
# 174              Zajčeva koča  Zasavsko - Posavsko hribovje in Dolenjska
# 2612                   Zaplaz  Zasavsko - Posavsko hribovje in Dolenjska
# 214       Zasavska Sveta gora  Zasavsko - Posavsko hribovje in Dolenjska
#
#       visina        vrsta  priljubljenost  mesto_priljubljenosti  \
# id
# ...

# %%
izleti.sort_values('priljubljenost')
# Out:
#                                   ime  \
# id
# 3001      Sv. Peter in Pavel (Perati)
# 2997              Sveti Duh (Labinje)
# 2881                        Smodivnik
# 2984                 Planina Zagreben
# 2992  Planja (nad Mangartsko planino)
# ...                               ...
# 52                        Begunjščica
# 77                           Viševnik
# 53                               Stol
# 150                               Krn
# 133      Koča pri Triglavskih jezerih
#
#                                             gorovje  visina  \
# id
# 3001                                  Julijske Alpe     812
# 2997  Škofjeloško, Cerkljansko hribovje in Jelovica     665
# 2881                                      Karavanke     923
# 2984                                  Julijske Alpe    1240
# 2992                                  Julijske Alpe    1553
# ...                                             ...     ...
# 52                                        Karavanke    2060
# ...

# %%
bolj_priljubljeni = izleti['priljubljenost'] > 80

# %%
nizji = izleti['visina'] < 1500

# %%
druzinski = izleti[bolj_priljubljeni & nizji]

# %%
druzinski.sort_values('priljubljenost')
# Out:
#                          ime                                        gorovje  \
# id
# 594              Hotel Golte                        Kamniško Savinjske Alpe
# 865          Dom na Sabotinu      Goriško, Notranjsko in Snežniško hribovje
# 1115                   Kojca  Škofjeloško, Cerkljansko hribovje in Jelovica
# 547        Koča na Ermanovcu  Škofjeloško, Cerkljansko hribovje in Jelovica
# 403       Veliki slap Kozjak                                  Julijske Alpe
# ...                      ...                                            ...
# 778                  Slavnik      Goriško, Notranjsko in Snežniško hribovje
# 223            Dom na Kofcah                                      Karavanke
# 178                     Krim      Goriško, Notranjsko in Snežniško hribovje
# 121      Koča na Kriški gori                        Kamniško Savinjske Alpe
# 471   Vojkova koča na Nanosu      Goriško, Notranjsko in Snežniško hribovje
#
# ...
